# %%
#Based on example at https://www.tensorflow.org/lite/performance/post_training_integer_quant

import logging
logging.getLogger("tensorflow").setLevel(logging.DEBUG)

try:
  # %tensorflow_version only exists in Colab.
  import tensorflow.compat.v2 as tf
except Exception:
  pass
tf.enable_v2_behavior()

from tensorflow import keras
import numpy as np
import pathlib
import pandas as pd
import cv2
from PIL import Image
from sklearn.model_selection import train_test_split    
    
#A function to view an array
def view(array):
    plt.imshow(array)
    plt.xticks(ticks=[])
    plt.yticks(ticks=[])
    plt.show()

#http://localhost:8889/edit/Documents/Python/google_coral_tests/real_big_properties_df.csv 
    
prop_df = pd.read_csv('real_big_properties_df.csv').drop(columns=['Unnamed: 0'])
numbers = list(prop_df.numbers)
numbers = np.array(numbers)
shapes = list(prop_df.shapes)
shapes = np.array(shapes)
fills = list(prop_df.fills)
fills = np.array(fills)
colors = list(prop_df.colors)
colors = np.array(colors)
numbers[246] = 0
numbers[84] = 0
fills[300] = 1
numbers[300] = 1
numbers[136] = 0
numbers[298] = 0
fills[298] = 2
numbers[85] = 2
numbers[297] = 1
numbers[302] = 2
numbers[247] = 2
numbers[135] = 1
numbers[140] = 2

# Load cards and labels
#real_big_array = np.load('real_big_array.npy')
gray_big_array = np.load('gray_big_array.npy')
gray_big_array.shape

########################
#Set image size
im_size = 100

gray_small_list = []
for i in range(gray_big_array.shape[0]):
    gray_small_list.append(cv2.resize(gray_big_array[i], (im_size,im_size)))
gray_small_array = np.stack(gray_small_list, axis=0)

#######################
#######################
#Shape training
X = gray_small_array
y = shapes
train_images, test_images, train_labels, test_labels = train_test_split(X, y, test_size=0.20, random_state=42)

tf.random.set_seed(42)

# Normalize the input image so that each pixel value is between 0 to 1.
train_images = train_images / 255.0
test_images = test_images / 255.0

# Define the model architecture.
model = keras.Sequential([
  keras.layers.InputLayer(input_shape=(im_size, im_size)),
  keras.layers.Reshape(target_shape=(im_size, im_size, 1)),
  keras.layers.Conv2D(filters=12, kernel_size=(3, 3), activation=tf.nn.relu),
  keras.layers.MaxPooling2D(pool_size=(2, 2)),
  keras.layers.Flatten(),
  keras.layers.Dense(16),
  keras.layers.Dense(3)
])

# Train the digit classification model
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

model.fit(
  train_images,
  train_labels,
  epochs=150,
  validation_split=0.1,
)

converter = tf.lite.TFLiteConverter.from_keras_model(model)
tflite_model = converter.convert()

###################
tflite_models_dir = pathlib.Path("/tmp/shape_tflite_models/")
tflite_models_dir.mkdir(exist_ok=True, parents=True)

tflite_model_file = tflite_models_dir/"shape_model.tflite"
tflite_model_file.write_bytes(tflite_model)
###################

converter.optimizations = [tf.lite.Optimize.OPTIMIZE_FOR_SIZE]

images = tf.cast(gray_small_array, tf.float32) / 255.0
mnist_ds = tf.data.Dataset.from_tensor_slices((images)).batch(1)
def representative_data_gen():
  for input_value in mnist_ds.take(100):
    yield [input_value]

converter.representative_dataset = representative_data_gen

tflite_model_quant = converter.convert()
tflite_model_quant_file = tflite_models_dir/"shape_model_quant.tflite"
tflite_model_quant_file.write_bytes(tflite_model_quant)

converter.target_spec.supported_ops = [tf.lite.OpsSet.TFLITE_BUILTINS_INT8]
converter.inference_input_type = tf.uint8
converter.inference_output_type = tf.uint8

tflite_model_quant = converter.convert()
tflite_model_quant_file = tflite_models_dir/"shape_model_quant_io.tflite"
tflite_model_quant_file.write_bytes(tflite_model_quant)

interpreter = tf.lite.Interpreter(model_path=str(tflite_model_file))
interpreter.allocate_tensors()

interpreter_quant = tf.lite.Interpreter(model_path=str(tflite_model_quant_file))
interpreter_quant.allocate_tensors()

open("SHAPE_100_1.tflite", "wb").write(tflite_model)
open("SHAPE_post_quant_100_1.tflite", "wb").write(tflite_model_quant)
# Out:
# Train on 353 samples, validate on 40 samples
# Epoch 1/150
# 353/353 [==============================] - 1s 2ms/sample - loss: 2.8454 - accuracy: 0.3711 - val_loss: 1.3262 - val_accuracy: 0.2250
# Epoch 2/150
# 353/353 [==============================] - 0s 1ms/sample - loss: 1.0705 - accuracy: 0.4334 - val_loss: 0.7127 - val_accuracy: 0.6750
# Epoch 3/150
# 353/353 [==============================] - 0s 1ms/sample - loss: 0.7753 - accuracy: 0.6261 - val_loss: 0.8280 - val_accuracy: 0.5250
# Epoch 4/150
# 353/353 [==============================] - 0s 1ms/sample - loss: 0.5988 - accuracy: 0.7592 - val_loss: 0.4626 - val_accuracy: 0.9750
# Epoch 5/150
# 353/353 [==============================] - 0s 1ms/sample - loss: 0.4221 - accuracy: 0.9462 - val_loss: 0.3506 - val_accuracy: 1.0000
# Epoch 6/150
# 353/353 [==============================] - 0s 1ms/sample - loss: 0.3377 - accuracy: 0.9575 - val_loss: 0.2424 - val_accuracy: 1.0000
# Epoch 7/150
# 353/353 [==============================] - 0s 1ms/sample - loss: 0.2257 - accuracy: 0.9972 - val_loss: 0.1904 - val_accuracy: 1.0000
# Epoch 8/150
# 353/353 [==============================] - 0s 1ms/sample - loss: 0.1327 - accuracy: 1.0000 - val_loss: 0.0916 - val_accuracy: 1.0000
# Epoch 9/150
# 353/353 [==============================] - 0s 1ms/sample - loss: 0.0869 - accuracy: 1.0000 - val_loss: 0.0702 - val_accuracy: 1.0000
# Epoch 10/150
# 353/353 [==============================] - 0s 1ms/sample - loss: 0.0664 - accuracy: 1.0000 - val_loss: 0.0699 - val_accuracy: 1.0000
# Epoch 11/150
# 353/353 [==============================] - 0s 1ms/sample - loss: 0.0516 - accuracy: 1.0000 - val_loss: 0.0507 - val_accuracy: 1.0000
# Epoch 12/150
# 353/353 [==============================] - 0s 1ms/sample - loss: 0.0430 - accuracy: 1.0000 - val_loss: 0.0431 - val_accuracy: 1.0000
# Epoch 13/150
# 353/353 [==============================] - 0s 1ms/sample - loss: 0.0368 - accuracy: 1.0000 - val_loss: 0.0351 - val_accuracy: 1.0000
# Epoch 14/150
# 353/353 [==============================] - 0s 1ms/sample - loss: 0.0367 - accuracy: 1.0000 - val_loss: 0.0306 - val_accuracy: 1.0000
# Epoch 15/150
# 353/353 [==============================] - 0s 1ms/sample - loss: 0.0271 - accuracy: 1.0000 - val_loss: 0.0295 - val_accuracy: 1.0000
# Epoch 16/150
# 353/353 [==============================] - 0s 1ms/sample - loss: 0.0232 - accuracy: 1.0000 - val_loss: 0.0369 - val_accuracy: 1.0000
# Epoch 17/150
# 353/353 [==============================] - 0s 1ms/sample - loss: 0.0212 - accuracy: 1.0000 - val_loss: 0.0294 - val_accuracy: 1.0000
# Epoch 18/150
# 353/353 [==============================] - 0s 1ms/sample - loss: 0.0188 - accuracy: 1.0000 - val_loss: 0.0220 - val_accuracy: 1.0000
# Epoch 19/150
# 353/353 [==============================] - 0s 1ms/sample - loss: 0.0182 - accuracy: 1.0000 - val_loss: 0.0472 - val_accuracy: 1.0000
# Epoch 20/150
# 353/353 [==============================] - 0s 1ms/sample - loss: 0.0366 - accuracy: 0.9972 - val_loss: 0.0246 - val_accuracy: 1.0000
# Epoch 21/150
# 353/353 [==============================] - 0s 1ms/sample - loss: 0.0295 - accuracy: 1.0000 - val_loss: 0.0177 - val_accuracy: 1.0000
# Epoch 22/150
# 353/353 [==============================] - 0s 1ms/sample - loss: 0.0181 - accuracy: 1.0000 - val_loss: 0.0223 - val_accuracy: 1.0000
# Epoch 23/150
# 353/353 [==============================] - 0s 1ms/sample - loss: 0.0120 - accuracy: 1.0000 - val_loss: 0.0161 - val_accuracy: 1.0000
# Epoch 24/150
# 353/353 [==============================] - 0s 1ms/sample - loss: 0.0106 - accuracy: 1.0000 - val_loss: 0.0171 - val_accuracy: 1.0000
# Epoch 25/150
# 353/353 [==============================] - 0s 1ms/sample - loss: 0.0098 - accuracy: 1.0000 - val_loss: 0.0144 - val_accuracy: 1.0000
# Epoch 26/150
# 353/353 [==============================] - 0s 1ms/sample - loss: 0.0090 - accuracy: 1.0000 - val_loss: 0.0142 - val_accuracy: 1.0000
# Epoch 27/150
# 353/353 [==============================] - 0s 1ms/sample - loss: 0.0086 - accuracy: 1.0000 - val_loss: 0.0146 - val_accuracy: 1.0000
# Epoch 28/150
# 353/353 [==============================] - 0s 1ms/sample - loss: 0.0087 - accuracy: 1.0000 - val_loss: 0.0113 - val_accuracy: 1.0000
# Epoch 29/150
# 353/353 [==============================] - 0s 1ms/sample - loss: 0.0083 - accuracy: 1.0000 - val_loss: 0.0115 - val_accuracy: 1.0000
# Epoch 30/150
# 353/353 [==============================] - 0s 1ms/sample - loss: 0.0073 - accuracy: 1.0000 - val_loss: 0.0133 - val_accuracy: 1.0000
# Epoch 31/150
# 353/353 [==============================] - 0s 1ms/sample - loss: 0.0069 - accuracy: 1.0000 - val_loss: 0.0114 - val_accuracy: 1.0000
# Epoch 32/150
# 353/353 [==============================] - 0s 1ms/sample - loss: 0.0068 - accuracy: 1.0000 - val_loss: 0.0109 - val_accuracy: 1.0000
# Epoch 33/150
# 353/353 [==============================] - 0s 1ms/sample - loss: 0.0067 - accuracy: 1.0000 - val_loss: 0.0108 - val_accuracy: 1.0000
# Epoch 34/150
# 353/353 [==============================] - 0s 1ms/sample - loss: 0.0061 - accuracy: 1.0000 - val_loss: 0.0100 - val_accuracy: 1.0000
# Epoch 35/150
# 353/353 [==============================] - 0s 1ms/sample - loss: 0.0059 - accuracy: 1.0000 - val_loss: 0.0107 - val_accuracy: 1.0000
# Epoch 36/150
# 353/353 [==============================] - 0s 1ms/sample - loss: 0.0056 - accuracy: 1.0000 - val_loss: 0.0099 - val_accuracy: 1.0000
# Epoch 37/150
# 353/353 [==============================] - 0s 1ms/sample - loss: 0.0054 - accuracy: 1.0000 - val_loss: 0.0098 - val_accuracy: 1.0000
# Epoch 38/150
# 353/353 [==============================] - 0s 1ms/sample - loss: 0.0052 - accuracy: 1.0000 - val_loss: 0.0090 - val_accuracy: 1.0000
# Epoch 39/150
# 353/353 [==============================] - 0s 1ms/sample - loss: 0.0050 - accuracy: 1.0000 - val_loss: 0.0099 - val_accuracy: 1.0000
# Epoch 40/150
# 353/353 [==============================] - 0s 1ms/sample - loss: 0.0048 - accuracy: 1.0000 - val_loss: 0.0099 - val_accuracy: 1.0000
# Epoch 41/150
# 353/353 [==============================] - 0s 1ms/sample - loss: 0.0046 - accuracy: 1.0000 - val_loss: 0.0088 - val_accuracy: 1.0000
# Epoch 42/150
# 353/353 [==============================] - 0s 1ms/sample - loss: 0.0045 - accuracy: 1.0000 - val_loss: 0.0080 - val_accuracy: 1.0000
# Epoch 43/150
# 353/353 [==============================] - 0s 1ms/sample - loss: 0.0048 - accuracy: 1.0000 - val_loss: 0.0061 - val_accuracy: 1.0000
# Epoch 44/150
# 353/353 [==============================] - 0s 1ms/sample - loss: 0.0041 - accuracy: 1.0000 - val_loss: 0.0104 - val_accuracy: 1.0000
# Epoch 45/150
# 353/353 [==============================] - 0s 1ms/sample - loss: 0.0041 - accuracy: 1.0000 - val_loss: 0.0077 - val_accuracy: 1.0000
# Epoch 46/150
# 353/353 [==============================] - 0s 1ms/sample - loss: 0.0038 - accuracy: 1.0000 - val_loss: 0.0079 - val_accuracy: 1.0000
# Epoch 47/150
# 353/353 [==============================] - 0s 1ms/sample - loss: 0.0037 - accuracy: 1.0000 - val_loss: 0.0074 - val_accuracy: 1.0000
# Epoch 48/150
# 353/353 [==============================] - 0s 1ms/sample - loss: 0.0036 - accuracy: 1.0000 - val_loss: 0.0096 - val_accuracy: 1.0000
# Epoch 49/150
# 353/353 [==============================] - 0s 1ms/sample - loss: 0.0087 - accuracy: 0.9972 - val_loss: 0.0043 - val_accuracy: 1.0000
# Epoch 50/150
# 353/353 [==============================] - 0s 1ms/sample - loss: 0.0060 - accuracy: 1.0000 - val_loss: 0.0052 - val_accuracy: 1.0000
# Epoch 51/150
# 353/353 [==============================] - 0s 1ms/sample - loss: 0.0039 - accuracy: 1.0000 - val_loss: 0.0096 - val_accuracy: 1.0000
# Epoch 52/150
# 353/353 [==============================] - 0s 1ms/sample - loss: 0.0033 - accuracy: 1.0000 - val_loss: 0.0082 - val_accuracy: 1.0000
# Epoch 53/150
# 353/353 [==============================] - 0s 1ms/sample - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.0055 - val_accuracy: 1.0000
# Epoch 54/150
# 353/353 [==============================] - 0s 1ms/sample - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.0068 - val_accuracy: 1.0000
# Epoch 55/150
# 353/353 [==============================] - 0s 1ms/sample - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.0069 - val_accuracy: 1.0000
# Epoch 56/150
# 353/353 [==============================] - 0s 1ms/sample - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.0056 - val_accuracy: 1.0000
# Epoch 57/150
# 353/353 [==============================] - 0s 1000us/sample - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.0069 - val_accuracy: 1.0000
# Epoch 58/150
# 353/353 [==============================] - 0s 1ms/sample - loss: 0.0034 - accuracy: 1.0000 - val_loss: 0.0081 - val_accuracy: 1.0000
# Epoch 59/150
# 353/353 [==============================] - 0s 997us/sample - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.0047 - val_accuracy: 1.0000
# Epoch 60/150
# 353/353 [==============================] - 0s 1ms/sample - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.0041 - val_accuracy: 1.0000
# Epoch 61/150
# 353/353 [==============================] - 0s 1ms/sample - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.0049 - val_accuracy: 1.0000
# Epoch 62/150
# 353/353 [==============================] - 0s 1ms/sample - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.0055 - val_accuracy: 1.0000
# Epoch 63/150
# 353/353 [==============================] - 1s 2ms/sample - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.0061 - val_accuracy: 1.0000
# Epoch 64/150
# 353/353 [==============================] - 0s 1ms/sample - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.0033 - val_accuracy: 1.0000
# Epoch 65/150
# 353/353 [==============================] - 0s 1ms/sample - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.0026 - val_accuracy: 1.0000
# Epoch 66/150
# 353/353 [==============================] - 0s 1ms/sample - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.0040 - val_accuracy: 1.0000
# Epoch 67/150
# 353/353 [==============================] - 0s 1ms/sample - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.0052 - val_accuracy: 1.0000
# Epoch 68/150
# 353/353 [==============================] - 0s 1ms/sample - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.0038 - val_accuracy: 1.0000
# Epoch 69/150
# 353/353 [==============================] - 0s 989us/sample - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.0040 - val_accuracy: 1.0000
# Epoch 70/150
# 353/353 [==============================] - 0s 1ms/sample - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.0046 - val_accuracy: 1.0000
# Epoch 71/150
# 353/353 [==============================] - 0s 1ms/sample - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.0039 - val_accuracy: 1.0000
# Epoch 72/150
# 353/353 [==============================] - 0s 995us/sample - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.0041 - val_accuracy: 1.0000
# Epoch 73/150
# 353/353 [==============================] - 0s 1ms/sample - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.0045 - val_accuracy: 1.0000
# Epoch 74/150
# 353/353 [==============================] - 0s 1ms/sample - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.0052 - val_accuracy: 1.0000
# Epoch 75/150
# 353/353 [==============================] - 0s 1ms/sample - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.0038 - val_accuracy: 1.0000
# Epoch 76/150
# 353/353 [==============================] - 0s 1ms/sample - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.0027 - val_accuracy: 1.0000
# Epoch 77/150
# 353/353 [==============================] - 0s 1ms/sample - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.0036 - val_accuracy: 1.0000
# Epoch 78/150
# 353/353 [==============================] - 0s 1ms/sample - loss: 0.0058 - accuracy: 1.0000 - val_loss: 0.0047 - val_accuracy: 1.0000
# Epoch 79/150
# 353/353 [==============================] - 0s 1ms/sample - loss: 0.0064 - accuracy: 1.0000 - val_loss: 0.0015 - val_accuracy: 1.0000
# Epoch 80/150
# 353/353 [==============================] - 0s 1ms/sample - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.0019 - val_accuracy: 1.0000
# Epoch 81/150
# 353/353 [==============================] - 0s 1ms/sample - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.0025 - val_accuracy: 1.0000
# Epoch 82/150
# 353/353 [==============================] - 0s 1ms/sample - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.0021 - val_accuracy: 1.0000
# Epoch 83/150
# 353/353 [==============================] - 0s 1ms/sample - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0018 - val_accuracy: 1.0000
# Epoch 84/150
# 353/353 [==============================] - 0s 1ms/sample - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0017 - val_accuracy: 1.0000
# Epoch 85/150
# 353/353 [==============================] - 0s 1ms/sample - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0020 - val_accuracy: 1.0000
# Epoch 86/150
# 353/353 [==============================] - 0s 1ms/sample - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0018 - val_accuracy: 1.0000
# Epoch 87/150
# 353/353 [==============================] - 0s 1ms/sample - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0018 - val_accuracy: 1.0000
# Epoch 88/150
# 353/353 [==============================] - 0s 1ms/sample - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0021 - val_accuracy: 1.0000
# Epoch 89/150
# 353/353 [==============================] - 0s 969us/sample - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.0021 - val_accuracy: 1.0000
# Epoch 90/150
# 353/353 [==============================] - 0s 1ms/sample - loss: 9.9602e-04 - accuracy: 1.0000 - val_loss: 0.0021 - val_accuracy: 1.0000
# Epoch 91/150
# 353/353 [==============================] - 0s 1ms/sample - loss: 9.7155e-04 - accuracy: 1.0000 - val_loss: 0.0022 - val_accuracy: 1.0000
# Epoch 92/150
# 353/353 [==============================] - 0s 1ms/sample - loss: 9.5064e-04 - accuracy: 1.0000 - val_loss: 0.0022 - val_accuracy: 1.0000
# Epoch 93/150
# 353/353 [==============================] - 0s 991us/sample - loss: 9.4146e-04 - accuracy: 1.0000 - val_loss: 0.0025 - val_accuracy: 1.0000
# Epoch 94/150
# 353/353 [==============================] - 0s 1ms/sample - loss: 9.4552e-04 - accuracy: 1.0000 - val_loss: 0.0025 - val_accuracy: 1.0000
# Epoch 95/150
# 353/353 [==============================] - 0s 1ms/sample - loss: 8.9726e-04 - accuracy: 1.0000 - val_loss: 0.0022 - val_accuracy: 1.0000
# Epoch 96/150
# 353/353 [==============================] - 0s 1ms/sample - loss: 8.6756e-04 - accuracy: 1.0000 - val_loss: 0.0023 - val_accuracy: 1.0000
# Epoch 97/150
# 353/353 [==============================] - 0s 1ms/sample - loss: 8.7151e-04 - accuracy: 1.0000 - val_loss: 0.0031 - val_accuracy: 1.0000
# Epoch 98/150
# 353/353 [==============================] - 0s 1ms/sample - loss: 9.3647e-04 - accuracy: 1.0000 - val_loss: 0.0032 - val_accuracy: 1.0000
# Epoch 99/150
# 353/353 [==============================] - 0s 1ms/sample - loss: 8.2509e-04 - accuracy: 1.0000 - val_loss: 0.0022 - val_accuracy: 1.0000
# Epoch 100/150
# 353/353 [==============================] - 0s 1ms/sample - loss: 8.1048e-04 - accuracy: 1.0000 - val_loss: 0.0017 - val_accuracy: 1.0000
# Epoch 101/150
# 353/353 [==============================] - 0s 1ms/sample - loss: 7.9721e-04 - accuracy: 1.0000 - val_loss: 0.0020 - val_accuracy: 1.0000
# Epoch 102/150
# 353/353 [==============================] - 0s 1ms/sample - loss: 7.7922e-04 - accuracy: 1.0000 - val_loss: 0.0022 - val_accuracy: 1.0000
# Epoch 103/150
# 353/353 [==============================] - 0s 1ms/sample - loss: 7.5918e-04 - accuracy: 1.0000 - val_loss: 0.0021 - val_accuracy: 1.0000
# Epoch 104/150
# 353/353 [==============================] - 0s 1ms/sample - loss: 7.4907e-04 - accuracy: 1.0000 - val_loss: 0.0022 - val_accuracy: 1.0000
# Epoch 105/150
# 353/353 [==============================] - 0s 1ms/sample - loss: 7.3811e-04 - accuracy: 1.0000 - val_loss: 0.0023 - val_accuracy: 1.0000
# Epoch 106/150
# 353/353 [==============================] - 0s 1ms/sample - loss: 7.2047e-04 - accuracy: 1.0000 - val_loss: 0.0024 - val_accuracy: 1.0000
# Epoch 107/150
# 353/353 [==============================] - 0s 1ms/sample - loss: 7.0812e-04 - accuracy: 1.0000 - val_loss: 0.0022 - val_accuracy: 1.0000
# Epoch 108/150
# 353/353 [==============================] - 0s 1ms/sample - loss: 6.9787e-04 - accuracy: 1.0000 - val_loss: 0.0021 - val_accuracy: 1.0000
# Epoch 109/150
# 353/353 [==============================] - 0s 1ms/sample - loss: 6.9228e-04 - accuracy: 1.0000 - val_loss: 0.0023 - val_accuracy: 1.0000
# Epoch 110/150
# 353/353 [==============================] - 0s 1ms/sample - loss: 6.8025e-04 - accuracy: 1.0000 - val_loss: 0.0023 - val_accuracy: 1.0000
# Epoch 111/150
# 353/353 [==============================] - 0s 1ms/sample - loss: 6.6847e-04 - accuracy: 1.0000 - val_loss: 0.0023 - val_accuracy: 1.0000
# Epoch 112/150
# 353/353 [==============================] - 0s 1ms/sample - loss: 6.5343e-04 - accuracy: 1.0000 - val_loss: 0.0023 - val_accuracy: 1.0000
# Epoch 113/150
# 353/353 [==============================] - 0s 1ms/sample - loss: 6.4196e-04 - accuracy: 1.0000 - val_loss: 0.0021 - val_accuracy: 1.0000
# Epoch 114/150
# 353/353 [==============================] - 0s 1ms/sample - loss: 6.3290e-04 - accuracy: 1.0000 - val_loss: 0.0020 - val_accuracy: 1.0000
# Epoch 115/150
# 353/353 [==============================] - 0s 1ms/sample - loss: 6.2632e-04 - accuracy: 1.0000 - val_loss: 0.0018 - val_accuracy: 1.0000
# Epoch 116/150
# 353/353 [==============================] - 0s 1ms/sample - loss: 6.3578e-04 - accuracy: 1.0000 - val_loss: 0.0015 - val_accuracy: 1.0000
# Epoch 117/150
# 353/353 [==============================] - 0s 1ms/sample - loss: 6.1336e-04 - accuracy: 1.0000 - val_loss: 0.0018 - val_accuracy: 1.0000
# Epoch 118/150
# 353/353 [==============================] - 0s 1ms/sample - loss: 5.9799e-04 - accuracy: 1.0000 - val_loss: 0.0020 - val_accuracy: 1.0000
# Epoch 119/150
# 353/353 [==============================] - 0s 1ms/sample - loss: 6.0152e-04 - accuracy: 1.0000 - val_loss: 0.0020 - val_accuracy: 1.0000
# Epoch 120/150
# 353/353 [==============================] - 0s 1ms/sample - loss: 5.8737e-04 - accuracy: 1.0000 - val_loss: 0.0023 - val_accuracy: 1.0000
# Epoch 121/150
# 353/353 [==============================] - 0s 1ms/sample - loss: 5.7475e-04 - accuracy: 1.0000 - val_loss: 0.0019 - val_accuracy: 1.0000
# Epoch 122/150
# 353/353 [==============================] - 0s 1ms/sample - loss: 5.6078e-04 - accuracy: 1.0000 - val_loss: 0.0020 - val_accuracy: 1.0000
# Epoch 123/150
# 353/353 [==============================] - 0s 1ms/sample - loss: 5.5276e-04 - accuracy: 1.0000 - val_loss: 0.0022 - val_accuracy: 1.0000
# Epoch 124/150
# 353/353 [==============================] - 0s 1ms/sample - loss: 5.4463e-04 - accuracy: 1.0000 - val_loss: 0.0023 - val_accuracy: 1.0000
# Epoch 125/150
# 353/353 [==============================] - 0s 1ms/sample - loss: 5.8354e-04 - accuracy: 1.0000 - val_loss: 0.0035 - val_accuracy: 1.0000
# Epoch 126/150
# 353/353 [==============================] - 0s 1ms/sample - loss: 5.7142e-04 - accuracy: 1.0000 - val_loss: 0.0021 - val_accuracy: 1.0000
# Epoch 127/150
# 353/353 [==============================] - 0s 1ms/sample - loss: 5.2448e-04 - accuracy: 1.0000 - val_loss: 0.0018 - val_accuracy: 1.0000
# Epoch 128/150
# 353/353 [==============================] - 0s 1ms/sample - loss: 5.1116e-04 - accuracy: 1.0000 - val_loss: 0.0018 - val_accuracy: 1.0000
# Epoch 129/150
# 353/353 [==============================] - 0s 1ms/sample - loss: 5.1777e-04 - accuracy: 1.0000 - val_loss: 0.0022 - val_accuracy: 1.0000
# Epoch 130/150
# 353/353 [==============================] - 0s 1ms/sample - loss: 5.0190e-04 - accuracy: 1.0000 - val_loss: 0.0020 - val_accuracy: 1.0000
# Epoch 131/150
# 353/353 [==============================] - 0s 1ms/sample - loss: 4.9247e-04 - accuracy: 1.0000 - val_loss: 0.0018 - val_accuracy: 1.0000
# Epoch 132/150
# 353/353 [==============================] - 0s 1ms/sample - loss: 4.8256e-04 - accuracy: 1.0000 - val_loss: 0.0020 - val_accuracy: 1.0000
# Epoch 133/150
# 353/353 [==============================] - 0s 1ms/sample - loss: 4.7774e-04 - accuracy: 1.0000 - val_loss: 0.0019 - val_accuracy: 1.0000
# Epoch 134/150
# 353/353 [==============================] - 0s 1ms/sample - loss: 4.7345e-04 - accuracy: 1.0000 - val_loss: 0.0018 - val_accuracy: 1.0000
# Epoch 135/150
# 353/353 [==============================] - 0s 1ms/sample - loss: 4.6468e-04 - accuracy: 1.0000 - val_loss: 0.0020 - val_accuracy: 1.0000
# Epoch 136/150
# 353/353 [==============================] - 0s 1ms/sample - loss: 4.5705e-04 - accuracy: 1.0000 - val_loss: 0.0019 - val_accuracy: 1.0000
# Epoch 137/150
# 353/353 [==============================] - 0s 1ms/sample - loss: 4.5223e-04 - accuracy: 1.0000 - val_loss: 0.0019 - val_accuracy: 1.0000
# Epoch 138/150
# 353/353 [==============================] - 0s 1ms/sample - loss: 4.4638e-04 - accuracy: 1.0000 - val_loss: 0.0019 - val_accuracy: 1.0000
# Epoch 139/150
# 353/353 [==============================] - 0s 1ms/sample - loss: 4.4562e-04 - accuracy: 1.0000 - val_loss: 0.0019 - val_accuracy: 1.0000
# Epoch 140/150
# 353/353 [==============================] - 0s 1ms/sample - loss: 4.3901e-04 - accuracy: 1.0000 - val_loss: 0.0021 - val_accuracy: 1.0000
# Epoch 141/150
# 353/353 [==============================] - 0s 1ms/sample - loss: 4.3405e-04 - accuracy: 1.0000 - val_loss: 0.0020 - val_accuracy: 1.0000
# Epoch 142/150
# 353/353 [==============================] - 0s 1ms/sample - loss: 4.3535e-04 - accuracy: 1.0000 - val_loss: 0.0020 - val_accuracy: 1.0000
# Epoch 143/150
# 353/353 [==============================] - 0s 1ms/sample - loss: 4.8466e-04 - accuracy: 1.0000 - val_loss: 0.0032 - val_accuracy: 1.0000
# Epoch 144/150
# 353/353 [==============================] - 0s 1ms/sample - loss: 4.4177e-04 - accuracy: 1.0000 - val_loss: 0.0016 - val_accuracy: 1.0000
# Epoch 145/150
# 353/353 [==============================] - 0s 1ms/sample - loss: 4.0156e-04 - accuracy: 1.0000 - val_loss: 0.0015 - val_accuracy: 1.0000
# Epoch 146/150
# 353/353 [==============================] - 0s 1ms/sample - loss: 4.0283e-04 - accuracy: 1.0000 - val_loss: 0.0015 - val_accuracy: 1.0000
# Epoch 147/150
# 353/353 [==============================] - 0s 1ms/sample - loss: 3.9170e-04 - accuracy: 1.0000 - val_loss: 0.0017 - val_accuracy: 1.0000
# Epoch 148/150
# 353/353 [==============================] - 0s 1ms/sample - loss: 3.8829e-04 - accuracy: 1.0000 - val_loss: 0.0019 - val_accuracy: 1.0000
# Epoch 149/150
# 353/353 [==============================] - 0s 1ms/sample - loss: 3.7981e-04 - accuracy: 1.0000 - val_loss: 0.0019 - val_accuracy: 1.0000
# Epoch 150/150
# 353/353 [==============================] - 0s 1ms/sample - loss: 3.7776e-04 - accuracy: 1.0000 - val_loss: 0.0019 - val_accuracy: 1.0000
# 464320
